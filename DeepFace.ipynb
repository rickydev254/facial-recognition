# %%
#pip install deepface

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
#import pandas as pd

# %%
img1_path = 'tests/dataset/img1.jpg'
img2_path = 'tests/dataset/img2.jpg'

# %%
img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
model_name = 'VGG-Face'

# %%
#variables passed to argument are required and should be named as defined
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name)
# Out:
# 2023-06-02 23:03:34.105275: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2023-06-02 23:03:35.114333: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2023-06-02 23:03:40.563699: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2023-06-02 23:03:48.409943: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# 2023-06-02 23:03:48.531385: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /home/imhotep/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [12:07<00:00, 798kB/s]

# %%
#on model change for comparison
resp
# Out:
# {'verified': True,
#  'distance': 0.25551898252856886,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 345, 'y': 211, 'w': 769, 'h': 769},
#   'img2': {'x': 516, 'y': 192, 'w': 512, 'h': 512}},
#  'time': 760.54}

# %%
#return a dictionary
resp
# Out:
# {'verified': True,
#  'distance': 0.24256998949322295,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 345, 'y': 211, 'w': 769, 'h': 769},
#   'img2': {'x': 516, 'y': 192, 'w': 512, 'h': 512}},
#  'time': 152.16}

# %%
df = DeepFace.find(img_path = 'source.jpg', db_path = '/tests/dataset/img1.jpg')

# %%
df.head()

# %%
obj = DeepFace.analyze(img_path = img1_path)
